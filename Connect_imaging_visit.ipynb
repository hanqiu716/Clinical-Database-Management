# %% [markdown]
# #### Aim: Import imaging_visit.csv into Mysql, fill table names imaging_raw"

# %%
import os
import pandas
import mysql
import io
import re

os.chdir('C:/Users/SpectralMD/Desktop/clindata')
os.path.abspath('.')
rootDir= '.'

filename='imaging_visit.csv'
#names = ['a', 'b', 'c']

data=pandas.read_csv(filename)
data=data.drop('Unnamed: 0', axis=1)
#data=data.drop('Status', axis=1) 
data2=data.columns = [x.lower() for x in data.columns]
df=data
df
# Out:
#    subjectnum subinit  visittype imagingdate datelastvisit  imagingtype  \
# 0    0001-001      DR        0.0  2016-04-08    2016-04-08          3.0
# 1    0001-002      JG        0.0  2016-04-08    2016-04-08          NaN
# 2    0001-003      DJ        0.0  2016-04-08    2016-04-08          3.0
# 3    0001-004      PD        0.0  2016-04-08    2016-04-08          3.0
# 4    0001-005     EIS        0.0  2016-04-11    2016-04-11          3.0
# 5    0001-006     ARB        0.0  2016-04-12    2016-04-12          3.0
# 6    0001-007     CGK        0.0  2016-04-12    2016-04-12          3.0
# 7    0001-008     MKG        0.0  2016-04-12    2016-04-12          3.0
# 8    0001-009     ARP        0.0  2016-04-15    2016-04-15          3.0
# 9    0001-010     DGH        0.0  2016-04-22    2016-04-22          3.0
# 10   0001-011     CDB        0.0  2016-04-22    2016-04-22          3.0
# 11   0001-012     RSB        0.0  2016-05-03    2016-05-03          3.0
# 12   0001-013     FWD        0.0  2016-05-13    2016-05-13          3.0
# 13   0001-014     LGZ        0.0  2016-05-13    2016-05-13          3.0
# 14   0001-015     REB        0.0  2016-05-13    2016-05-13          3.0
# 15   0001-016     RLS        0.0  2016-05-20    2016-05-20          3.0
# 16   0001-018     GMW        0.0  2016-06-06    2016-06-06          1.0
# 17   0001-019     BJF        0.0  2016-06-07    2016-06-07          3.0
# 18   0001-020     JDB        0.0  2016-06-20    2016-06-20          3.0
# 19   0001-017     NaN        NaN         NaN           NaN          NaN
#
#     imagingnumber     hr    rr    sbp  ...    epithelialization  woundtemp  \
# 0             3.0   92.0  18.0  157.0  ...                  0.0        0.0
# 1             NaN   66.0  22.0  176.0  ...                  0.0        0.0
# 2             NaN   83.0  16.0  189.0  ...                  0.0        0.0
# 3             NaN   70.0  16.0  104.0  ...                  0.0        0.0
# 4             NaN   65.0  18.0  121.0  ...                  0.0        2.0
# 5             NaN   83.0  18.0  146.0  ...                  0.0        0.0
# 6             NaN   92.0  22.0  144.0  ...                  4.0        0.0
# 7             NaN   65.0  18.0  151.0  ...                  0.0        0.0
# 8             NaN   76.0  14.0  136.0  ...                  0.0        0.0
# 9             8.0   88.0  16.0  156.0  ...                  0.0        0.0
# 10            4.0   78.0  16.0  141.0  ...                  0.0        0.0
# 11           17.0   88.0  18.0  158.0  ...                  0.0        1.0
# 12            2.0   57.0  18.0  127.0  ...                  0.0        0.0
# 13            2.0   96.0  18.0  144.0  ...                  0.0        1.0
# 14           30.0   74.0  18.0  112.0  ...                  NaN        NaN
# 15            3.0   77.0  18.0  154.0  ...                  NaN        NaN
# 16            3.0   68.0  20.0  125.0  ...                  NaN        NaN
# 17            7.0  107.0  12.0  155.0  ...                  NaN        NaN
# 18           13.0   66.0  12.0  147.0  ...                  NaN        NaN
# 19            NaN    NaN   NaN    NaN  ...                  NaN        NaN
#
#     infection  localpulse  exudateamount  exudatetype  length  width  depth  \
# 0         1.0         0.0            3.0          3.0     NaN    NaN    NaN
# 1         0.0         0.0            1.0          3.0     0.2    0.1    0.1
# 2         0.0         0.0            0.0          3.0     2.0    2.1    0.3
# 3         0.0         0.0            1.0          1.0     0.3    0.4    0.2
# 4         0.0         NaN            NaN          NaN     3.0    3.0    0.1
# 5         0.0         0.0            1.0          3.0     1.5    0.5    0.1
# 6         0.0         0.0            1.0          3.0     NaN    NaN    NaN
# 7         0.0         0.0            3.0          3.0     1.8    2.4    0.2
# 8         0.0         0.0            3.0          3.0     5.8    5.0    0.2
# 9         0.0         1.0            1.0          3.0     1.0    1.0    0.2
# 10        0.0         0.0            3.0          3.0     8.2    2.2    0.2
# 11        0.0         0.0            4.0          3.0     NaN    NaN    NaN
# 12        0.0         0.0            3.0          2.0     2.0    2.0    0.5
# 13        1.0         0.0            3.0          3.0     0.3    0.8    1.8
# 14        NaN         0.0            NaN          NaN     NaN    NaN    NaN
# 15        1.0         NaN            NaN          NaN     NaN    NaN    NaN
# 16        NaN         NaN            NaN          NaN     NaN    NaN    NaN
# 17        1.0         0.0            NaN          NaN     NaN    NaN    NaN
# 18        1.0         NaN            NaN          NaN     NaN    NaN    NaN
# 19        NaN         NaN            NaN          NaN     NaN    NaN    NaN
#
#      temp
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4   37.00
# 5   36.78
# 6   36.78
# 7   37.06
# 8   36.67
# 9   36.78
# 10  36.94
# 11    NaN
# 12  36.67
# 13  37.11
# 14  36.40
# 15  37.17
# 16  36.61
# 17  35.30
# 18  36.70
# 19    NaN
#
# [20 rows x 72 columns]

# %%
def date(x):
    
    num = x.split('-')
    newdate = num[0]+ num[1]+num[2]
    return newdate

# %%
for i in range(len(df)):
    if type(df['imagingdate'][i])==str:
        df['imagingdate'][i]=date(df['imagingdate'][i])
    else:
        df['imagingdate'][i]='0'
# Out:
# C:\Users\SpectralMD\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\SpectralMD\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df
# Out:
#    subjectnum subinit  visittype imagingdate datelastvisit  imagingtype  \
# 0    0001-001      DR        0.0    20160408    2016-04-08          3.0
# 1    0001-002      JG        0.0    20160408    2016-04-08          NaN
# 2    0001-003      DJ        0.0    20160408    2016-04-08          3.0
# 3    0001-004      PD        0.0    20160408    2016-04-08          3.0
# 4    0001-005     EIS        0.0    20160411    2016-04-11          3.0
# 5    0001-006     ARB        0.0    20160412    2016-04-12          3.0
# 6    0001-007     CGK        0.0    20160412    2016-04-12          3.0
# 7    0001-008     MKG        0.0    20160412    2016-04-12          3.0
# 8    0001-009     ARP        0.0    20160415    2016-04-15          3.0
# 9    0001-010     DGH        0.0    20160422    2016-04-22          3.0
# 10   0001-011     CDB        0.0    20160422    2016-04-22          3.0
# 11   0001-012     RSB        0.0    20160503    2016-05-03          3.0
# 12   0001-013     FWD        0.0    20160513    2016-05-13          3.0
# 13   0001-014     LGZ        0.0    20160513    2016-05-13          3.0
# 14   0001-015     REB        0.0    20160513    2016-05-13          3.0
# 15   0001-016     RLS        0.0    20160520    2016-05-20          3.0
# 16   0001-018     GMW        0.0    20160606    2016-06-06          1.0
# 17   0001-019     BJF        0.0    20160607    2016-06-07          3.0
# 18   0001-020     JDB        0.0    20160620    2016-06-20          3.0
# 19   0001-017     NaN        NaN           0           NaN          NaN
#
#     imagingnumber     hr    rr    sbp  ...    epithelialization  woundtemp  \
# 0             3.0   92.0  18.0  157.0  ...                  0.0        0.0
# 1             NaN   66.0  22.0  176.0  ...                  0.0        0.0
# 2             NaN   83.0  16.0  189.0  ...                  0.0        0.0
# 3             NaN   70.0  16.0  104.0  ...                  0.0        0.0
# 4             NaN   65.0  18.0  121.0  ...                  0.0        2.0
# 5             NaN   83.0  18.0  146.0  ...                  0.0        0.0
# 6             NaN   92.0  22.0  144.0  ...                  4.0        0.0
# 7             NaN   65.0  18.0  151.0  ...                  0.0        0.0
# 8             NaN   76.0  14.0  136.0  ...                  0.0        0.0
# 9             8.0   88.0  16.0  156.0  ...                  0.0        0.0
# 10            4.0   78.0  16.0  141.0  ...                  0.0        0.0
# 11           17.0   88.0  18.0  158.0  ...                  0.0        1.0
# 12            2.0   57.0  18.0  127.0  ...                  0.0        0.0
# 13            2.0   96.0  18.0  144.0  ...                  0.0        1.0
# 14           30.0   74.0  18.0  112.0  ...                  NaN        NaN
# 15            3.0   77.0  18.0  154.0  ...                  NaN        NaN
# 16            3.0   68.0  20.0  125.0  ...                  NaN        NaN
# 17            7.0  107.0  12.0  155.0  ...                  NaN        NaN
# 18           13.0   66.0  12.0  147.0  ...                  NaN        NaN
# 19            NaN    NaN   NaN    NaN  ...                  NaN        NaN
#
#     infection  localpulse  exudateamount  exudatetype  length  width  depth  \
# 0         1.0         0.0            3.0          3.0     NaN    NaN    NaN
# 1         0.0         0.0            1.0          3.0     0.2    0.1    0.1
# 2         0.0         0.0            0.0          3.0     2.0    2.1    0.3
# 3         0.0         0.0            1.0          1.0     0.3    0.4    0.2
# 4         0.0         NaN            NaN          NaN     3.0    3.0    0.1
# 5         0.0         0.0            1.0          3.0     1.5    0.5    0.1
# 6         0.0         0.0            1.0          3.0     NaN    NaN    NaN
# 7         0.0         0.0            3.0          3.0     1.8    2.4    0.2
# 8         0.0         0.0            3.0          3.0     5.8    5.0    0.2
# 9         0.0         1.0            1.0          3.0     1.0    1.0    0.2
# 10        0.0         0.0            3.0          3.0     8.2    2.2    0.2
# 11        0.0         0.0            4.0          3.0     NaN    NaN    NaN
# 12        0.0         0.0            3.0          2.0     2.0    2.0    0.5
# 13        1.0         0.0            3.0          3.0     0.3    0.8    1.8
# 14        NaN         0.0            NaN          NaN     NaN    NaN    NaN
# 15        1.0         NaN            NaN          NaN     NaN    NaN    NaN
# 16        NaN         NaN            NaN          NaN     NaN    NaN    NaN
# 17        1.0         0.0            NaN          NaN     NaN    NaN    NaN
# 18        1.0         NaN            NaN          NaN     NaN    NaN    NaN
# 19        NaN         NaN            NaN          NaN     NaN    NaN    NaN
#
#      temp
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4   37.00
# 5   36.78
# 6   36.78
# 7   37.06
# 8   36.67
# 9   36.78
# 10  36.94
# 11    NaN
# 12  36.67
# 13  37.11
# 14  36.40
# 15  37.17
# 16  36.61
# 17  35.30
# 18  36.70
# 19    NaN
#
# [20 rows x 72 columns]

# %%
import mysql.connector
import sqlalchemy
from sqlalchemy import create_engine

engine = create_engine('mysql+mysqlconnector://root:123456@localhost/clinical_info')
connection = engine.connect()
trans = connection.begin()

# %%
df.to_sql('imaging_raw', engine, if_exists='replace')
trans.commit()
